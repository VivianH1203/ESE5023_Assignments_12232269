# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import math
# %matplotlib inline

# %% [markdown]
# # 1

# %%
ds1 = pd.read_csv(r'D:\Sustech\研究生\课程\Environmental programming\ESE5023_Assignments_12232269\Assignment 04\usgs_earthquakes.csv',sep=',')
ds1
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.20  1.10      ml
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.00  1.33      ml
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.10  1.30      ml
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.50  0.80      ml
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.59  1.34      ml
# ...                         ...        ...         ...     ...   ...     ...
# 120103  2014-12-01 00:10:16.000  60.963900 -146.762900   14.80  3.80      ml
# 120104  2014-12-01 00:09:39.000  58.869100 -154.415900  108.40  2.40      ml
# 120105  2014-12-01 00:09:25.350  38.843498 -122.825836    2.37  0.43      md
# 120106  2014-12-01 00:05:54.000  65.152100 -148.992000    9.50  0.40      ml
# 120107  2014-12-01 00:04:05.000  60.227200 -147.024500    2.50  1.60      ml
#
# ...

# %%
ds2 = ds1.sort_values('mag',ascending=False)
#since some events share the same magnitude, so there are maybe more than 50 earthquakes when sorted through magnitude
mag_threshold = ds2.iloc[49,4]
ds2 = ds2[ds2['mag'] >= mag_threshold]
ds2
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 37371   2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww
# 50562   2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww
# 36918   2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww
# 33808   2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww
# 31496   2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww
# 33537   2014-04-13 12:36:19.230  -11.4633   162.0511   39.00  7.4     mww
# 95913   2014-10-14 03:51:34.460   12.5262   -88.1225   40.00  7.3     mww
# 31850   2014-04-18 14:27:24.920   17.3970  -100.9723   24.00  7.2     mww
# 34318   2014-04-11 07:07:23.130   -6.5858   155.0485   60.53  7.1     mww
# 106285  2014-11-15 02:31:41.720    1.8929   126.5217   45.00  7.1     mww
# 111052  2014-11-01 18:57:22.380  -19.6903  -177.7587  434.00  7.1     mww
# 97602   2014-10-09 02:14:31.440  -32.1082  -110.8112   16.54  7.0     mww
# ...

# %%
plt.figure(figsize=(5,5), dpi=300)
ax = plt.axes(projection=ccrs.Robinson(central_longitude=180))
ax.stock_img()
p1 = ax.scatter(ds2['longitude'], ds2['latitude'], c=ds2['mag'], s=10, ec='k',transform=ccrs.PlateCarree(),cmap='Reds',lw=0.7)
ax.set_title('Top 50 Earthquakes of 2014',fontsize=10)
cb1 = plt.colorbar(p1,fraction=0.02)
cb1.ax.tick_params(labelsize=6, length=1.5,width=1)
cb1.set_label('magnitude', fontdict={'family':'Arial', 'size': 6})

# %% [markdown]
# # 2

# %% [markdown]
# Dataset: CRU TS v4.07 temperature 2011-2020

# %%
ds2 = xr.open_dataset('D:\ESE5023data\cru_ts4.07.2011.2020.tmp.dat.nc')
ds2
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 120)
# Coordinates:
#   * lon      (lon) float32 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float32 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * time     (time) datetime64[ns] 2011-01-16 2011-02-15 ... 2020-12-16
# Data variables:
#     tmp      (time, lat, lon) float32 ...
#     stn      (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.4
#     title:        CRU TS4.07 Mean Temperature
#     institution:  Data held at British Atmospheric Data Centre, RAL, UK.
#     source:       Run ID = 2304141047. Data generated from:tmp.2304141039.dtb
#     history:      Fri 14 Apr 11:30:51 BST 2023 : User f098 : Program makegrid...
#     references:   Information on the data is available at http://badc.nerc.ac...
#     comment:      Access to these data is available to any registered CEDA user.
#     contact:      support@ceda.ac.uk

# %%
def gridline(ax, data, str1, str2, fontsize, lw, sp):
# --设置网格点属性
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
        linewidth=lw, color='k', alpha=0.5, linestyle='--')
    gl.top_labels = False  # 关闭顶端的经纬度标签
    gl.right_labels = False  # 关闭右侧的经纬度标签
    gl.xformatter = LONGITUDE_FORMATTER  # x轴设为经度的格式
    gl.yformatter = LATITUDE_FORMATTER  # y轴设为纬度的格式

    maxlong = math.ceil(max(np.unique(data.coords[str1].values)))
    minlong = int(min(np.unique(data.coords[str1].values)))
    maxlat = math.ceil(max(np.unique(data.coords[str2].values)))
    minlat = int(min(np.unique(data.coords[str2].values)))
    gl.xlocator = mticker.FixedLocator(np.arange(-180, 181, sp))
    gl.ylocator = mticker.FixedLocator(np.arange(-90, 91, sp))
    gl.xlabel_style = {'size': fontsize, 'family':'Arial'}
    gl.ylabel_style = {'size': fontsize, 'family': 'Arial'}

# %%
tmpmean = ds2['tmp'].mean(axis=0)
plt.figure(figsize=(5,5), dpi=300)
ax = plt.axes(projection=ccrs.Robinson())
ax.add_feature(cfeature.LAND,ec='k',fc='none',zorder=0)
p1 = tmpmean.plot(x='lon', y='lat', transform=ccrs.PlateCarree(),cmap='RdBu_r',alpha=0.7,add_colorbar=False,zorder=0)
ax.set_title('Mean temperature',fontsize=10)
ax.set_xlabel('Longitude',fontsize=8)
ax.set_ylabel('Latitude',fontsize=8)
plt.annotate('No data in CRU',(0,-85),xytext=(85,-55),transform=ccrs.PlateCarree(),fontsize=6,arrowprops=dict(shrink=0.1,width=1,fc='k'))
gridline(ax, tmpmean, 'lon', 'lat', 4, 0.2,30)
cb1 = plt.colorbar(p1,fraction=0.02)
cb1.ax.tick_params(labelsize=6, length=1.5,width=1)
cb1.set_label('Temperature ($^{\circ}$C)', fontdict={'family':'Arial', 'size': 6})

# %%
tmpmean = ds2['tmp'].mean(axis=0)
plt.figure(figsize=(5,5), dpi=300)
ax = plt.axes(projection=ccrs.Mercator())
ax.set_extent([70,150,10,50])
ax.add_feature(cfeature.LAND,ec='k',fc='none',zorder=0)
p1 = tmpmean.plot(x='lon', y='lat', transform=ccrs.PlateCarree(),cmap='RdBu_r',alpha=0.7,add_colorbar=False,zorder=0)
ax.set_title('Regional mean temperature',fontsize=10)
ax.set_xlabel('Longitude',fontsize=8)
ax.set_ylabel('Latitude',fontsize=8)
ax.annotate('China',(115,30),xytext=(130,20),transform=ccrs.PlateCarree(),fontsize=8,arrowprops=dict(shrink=0.1,width=1,fc='k'))
gridline(ax, tmpmean, 'lon', 'lat', 6, 0.2,10)
cb1 = plt.colorbar(p1,fraction=0.02)
cb1.ax.tick_params(labelsize=6, length=1.5,width=1)
cb1.set_label('Temperature ($^{\circ}$C)', fontdict={'family':'Arial', 'size': 6})
